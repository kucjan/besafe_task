# %% [markdown]
# ### Notebook for testing trained model with dataset different from training data

# %%
import tensorflow_addons as tfa
from random import randint
from dataset_generator import LineDatasetGenerator
from loaded_model import LoadedModel
from constants import *

# %%
MODEL_PATH = "../models/line_detector_v5/"

# %%
data_gen = LineDatasetGenerator(IMAGE_SIZE)

# %%
SET_SIZE = 2000
images, results = data_gen.create_set(SET_SIZE)

# %%
loaded_model = LoadedModel(MODEL_PATH, images, results, custom_objects={'RSquare': tfa.metrics.RSquare})
# Out:
# 63/63 [==============================] - 1s 8ms/step

# %%
rounded_acc = loaded_model.rounded_acc(2.5)
rounded_acc
# Out:
# 0.038

# %%
loaded_model.draw_prediction(randint(0, SET_SIZE-1))
